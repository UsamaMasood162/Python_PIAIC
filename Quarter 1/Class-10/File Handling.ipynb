# %% [raw]
# converting data into number is called vectorization
# data type float
# MTA 98-381 islamabad(fb group)

# %% [raw]
# Library
# beautifull soup for (web scrapping)
# sellinum for automation
# pyqt5
# pyautogui

# %%
File handling operation
read [we can read and manipulate data]
write [write into the data]
write after seek []
create []
truncate []
position at start []
position at end []

# %% [raw]
#                     |   r  r+  w  w+  a  a+
# --------------------|----------------------------
# read                |   +  +      +      +
#                     |
# write               |      +   +  +   +  +
#                     |
# write after seek    |      +   +  +
#                     |
# create              |          +  +   +  +
#                     |
# truncate            |          +  +
#                     |
# position at start   |   +  +   +  +
#                     |
# position at end     |                 +

# %%
abolute path saraa path start say end tak
relative  path sirf usi file ya folder ka
../ previos jany k liye

# %%
# %pwd
# Out:
# 'C:\\Users\\USAMA\\Documents\\PIAIC\\Class-10'

# %%
#absolute path
# %load /Users/USAMA/Documents/PIAIC/Class-10/TXT.txt
hello

# %%
#relative path
# %load TXT.txt
hello

# %%
open('TXT.txt')
# Out:
# <_io.TextIOWrapper name='TXT.txt' mode='r' encoding='cp1252'>

# %%
list(open('TXT.txt'))
# Out:
# ['hello']

# %%
data = open('TXT.txt')
print(type(data))
print(data)
data.close()
# Out:
# <class '_io.TextIOWrapper'>
# <_io.TextIOWrapper name='TXT.txt' mode='r' encoding='cp1252'>

# %%
data = open('TXT.txt')
for r in data:
    print(r)
data.close()
# Out:
# hello

# %%
#with open(file) as <variable>:
with open('TXT.txt',mode='r') as f:
    content = f.read()
    print(type(content))
    print(content)
    #problem in read function
    ##if data is huge like 20GB then read function creating problem
    ###batch size main chunks utha skty hy
# Out:
# <class 'str'>
# hello

# %%
#with open(file) as <variable>:
with open('TXT.txt',mode='r') as f:
    content = f.read()
    print(type(content))
    print(content)
# Out:
# <class 'str'>
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
#with open(file) as <variable>:
with open('TXT.txt',mode='r') as f:
    content = f.readlines()
    print(type(content))
    print(content)
# Out:
# <class 'list'>
# ['hello\n', 'hello\n']

# %%
#with open(file) as <variable>:
with open('TXT.txt',mode='r') as f:
    f.write("pakistan zindabad!!!!")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-28-0094f2d1027e> in <module>
#       1 #with open(file) as <variable>:
#       2 with open('TXT.txt',mode='r') as f:
# ----> 3     f.write("pakistan zindabad!!!!")
#       4
#
# UnsupportedOperation: not writable

# %%
with open('abc.txt',mode='w') as f:
    f.write("pakistan zinda bad______")
    #file generate ho gyi hy abc.txt name ki

# %%
with open('abc.txt',mode='w') as f:
    f.write("pakistan zinda bad______")

# %%
with open('abc.txt',mode='w') as f:
    print(f.readlines())
    f.write("pakistan zinda bad______")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-31-ece97346b0e5> in <module>
#       1 with open('abc.txt',mode='w') as f:
# ----> 2     print(f.readlines())
#       3     f.write("pakistan zinda bad______")
#
# UnsupportedOperation: not readable

# %%
with open('abc2.txt','a') as f:
    f.write(" ahmad\n") #name change karta ry gay to new data save hota rhy ga file main write() ki command say
    #r sirf read
    #w sirf tempary write
    #a perpanant write

# %%
with open('abc.txt','a+') as f:
    f.write("adan")
    print(f.readlines())
# Out:
# []

# %%
with open('abc.txt','a+') as f:
    f.write("rauf")
    f.seek(0)
    print(f.readlines())
# Out:
# ['adanrauf']

# %%
# relative path
# %load a.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3643         try:                                              # User namespace
# -> 3644             codeobj = eval(target, self.user_ns)
#    3645         except Exception:
#
# <string> in <module>
#
# NameError: name 'a' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8ee4e0a5ed8d> in <module>
# ----> 1 get_ipython().run_line_magic('load', 'a.py')
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
# ...

# %% [markdown]
# # task

# %%
with open('t.txt','a') as f:
    f.write("1 2 3")

# %%
with open('t1.txt','r+') as f:
    a = f.readlines()
    print(a)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-2b1a8dc1915c> in <module>
# ----> 1 with open('t1.txt','r+') as f:
#       2     a = f.readlines()
#       3     print(a)
#
# FileNotFoundError: [Errno 2] No such file or directory: 't1.txt'

# %%
open?? # wo list open hoti hy

# %%
with open ('abc5.txt','x') as f: # x is liye use hota huy k har dfa new file bny
    f.write("hello")

# %% [markdown]
# # load the data

# %% [markdown]
# # 1st method

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('./3.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (800, 1200, 3)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('./3.jpg')
print(img.shape)
print(img[0])
plt.imshow(img)
# Out:
# (800, 1200, 3)
# [[ 6  7  9]
#  [ 7  8 10]
#  [10 11 13]
#  ...
#  [ 4  5  7]
#  [ 5  6  8]
#  [ 6  7  9]]

# %% [markdown]
# # 2 method

# %%
from PIL import Image
image = Image.open("./3.jpg")
image.show()

# %%
import cv2
image = cv2.imread('./3.jpg')
plt.imshow(image)
plt.show()

# %%
import cv2
im = cv2.imread("./3.jpg" )
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  
im.shape
plt.imshow(im)

# %%
import numpy as np
im = np.array(Image.open('3.jpg').convert('L'))
plt.imshow(im)
plt.show()

# %%
from keras.preprocessing import image

X_test=image.load_img('3.jpeg',target_size=(28,28),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size 
X_test=image.img_to_array(X_test); #convert image into array
print(X_test.shape)
plt.imshow(X_test/255)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-1cbf4de2c405> in <module>
# ----> 1 from keras.preprocessing import image
#       2
#       3 X_test=image.load_img('3.jpeg',target_size=(28,28),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size
#       4 X_test=image.img_to_array(X_test); #convert image into array
#       5 print(X_test.shape)
#
# ModuleNotFoundError: No module named 'keras'

# %%
import numpy as np
im = np.array(Image.open('3.jpg').convert('L'))
plt.imshow(im)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(im, cmap=plt.get_cmap('gray'))

# %%
from scipy.io import wavfile
rate1,dat1 = wavfile.read('Ap.mp3')
print(rate1)
print(dat1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-e003e61ce13f> in <module>
#       1 from scipy.io import wavfile
# ----> 2 rate1,dat1 = wavfile.read('Ap.mp3')
#       3 print(rate1)
#       4 print(dat1)
#
# ~\Anaconda3\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     231         mmap = False
#     232     else:
# --> 233         fid = open(filename, 'rb')
#     234
#     235     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ap.mp3'
